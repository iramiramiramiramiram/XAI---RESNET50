# %% [markdown]
# # Import Libraries & Load Data

# %%
import json
import math
import os
import cv2
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras import layers
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.applications.densenet import DenseNet201
from keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.applications.inception_v3 import InceptionV3
#from keras.layers import Input
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score, confusion_matrix
import scipy
from tqdm import tqdm
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
import warnings
warnings.simplefilter("ignore")

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
            img = cv2.resize(img, (RESIZE,RESIZE))          
            IMG.append(np.array(img))
            
    return IMG

benign_train = np.array(Dataset_loader('/kaggle/input/breast-cancer-diagnosis/breast-cancer-dataset/Train/Benign',224))
malign_train = np.array(Dataset_loader('/kaggle/input/breast-cancer-diagnosis/breast-cancer-dataset/Train/Malignant',224))
benign_test = np.array(Dataset_loader('/kaggle/input/breast-cancer-diagnosis/breast-cancer-dataset/Test/Benign',224))
malign_test = np.array(Dataset_loader('/kaggle/input/breast-cancer-diagnosis/breast-cancer-dataset/Test/Malignant',224))
# Out:
# 100%|██████████| 640/640 [00:05<00:00, 126.20it/s]
# 100%|██████████| 640/640 [00:03<00:00, 160.64it/s]
# 100%|██████████| 120/120 [00:00<00:00, 122.23it/s]
# 100%|██████████| 120/120 [00:01<00:00, 104.32it/s]

# %%
benign_train.shape
# Out:
# (640, 224, 224, 3)

# %% [markdown]
# # Data Preprocessing

# %%
# Create labels
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# %%
# Merge data 
x_train = np.concatenate((benign_train, malign_train), axis = 0)
y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
x_test = np.concatenate((benign_test, malign_test), axis = 0)
y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# %%
# Shuffle train data
s = np.arange(x_train.shape[0])
np.random.shuffle(s)
x_train = x_train[s]
y_train = y_train[s]

# %%
# Shuffle test data
s = np.arange(x_test.shape[0])
np.random.shuffle(s)
x_test = x_test[s]
y_test = y_test[s]

# %%
# To categorical
y_train = to_categorical(y_train, num_classes= 2)
y_test = to_categorical(y_test, num_classes= 2)

# %%
# split dataset into train and validation
x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, 
    test_size=0.2, 
    random_state=11
)

# %%
# visualization image
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(x_train[i], interpolation='nearest')
plt.show()

# %%
BATCH_SIZE = 16

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True,  # randomly flip images
    )

# %% [markdown]
# # Define Model

# %%
def build_model(backbone, lr=1e-4):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(2, activation='softmax'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['accuracy']
    )
    
    return model

res = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
# resnet = DenseNet201(
#     weights='imagenet',
#     include_top=False,
#     input_shape=(224,224,3)
)

model = build_model(res ,lr = 1e-4)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  batch_normalization_94 (Bat  (None, 2048)             8192
#  chNormalization)
#
#  dense (Dense)               (None, 2)                 4098
#
# =================================================================
# Total params: 21,815,074
# Trainable params: 21,776,546
# Non-trainable params: 38,528
# _________________________________________________________________

# %% [markdown]
# # Training & Evaluation

# %%
learn_control = ReduceLROnPlateau(monitor='val_acc', patience=5,
                                verbose=1,factor=0.2, min_lr=1e-7)


history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=100,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 64s 281ms/step - loss: 0.8342 - accuracy: 0.5967 - val_loss: 4846809.0000 - val_accuracy: 0.5156
# Epoch 2/100
# 64/64 [==============================] - 15s 228ms/step - loss: 0.5926 - accuracy: 0.7178 - val_loss: 4931.6562 - val_accuracy: 0.5156
# Epoch 3/100
# 64/64 [==============================] - 15s 232ms/step - loss: 0.5287 - accuracy: 0.7783 - val_loss: 90.4838 - val_accuracy: 0.5156
# Epoch 4/100
# 64/64 [==============================] - 14s 223ms/step - loss: 0.4958 - accuracy: 0.7764 - val_loss: 0.5641 - val_accuracy: 0.7969
# Epoch 5/100
# 64/64 [==============================] - 15s 229ms/step - loss: 0.5548 - accuracy: 0.7617 - val_loss: 1.2000 - val_accuracy: 0.5508
# Epoch 6/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.6009 - accuracy: 0.7051 - val_loss: 1835981.7500 - val_accuracy: 0.5156
# Epoch 7/100
# 64/64 [==============================] - 15s 228ms/step - loss: 0.5701 - accuracy: 0.7373 - val_loss: 915.0941 - val_accuracy: 0.5156
# Epoch 8/100
# 64/64 [==============================] - 15s 226ms/step - loss: 0.5561 - accuracy: 0.7627 - val_loss: 2.2084 - val_accuracy: 0.6797
# Epoch 9/100
# 64/64 [==============================] - 15s 230ms/step - loss: 0.5099 - accuracy: 0.8047 - val_loss: 1269.5709 - val_accuracy: 0.5156
# Epoch 10/100
# 64/64 [==============================] - 14s 223ms/step - loss: 0.5344 - accuracy: 0.7646 - val_loss: 4.6879 - val_accuracy: 0.5781
# Epoch 11/100
# 64/64 [==============================] - 15s 229ms/step - loss: 0.5408 - accuracy: 0.7529 - val_loss: 23.8707 - val_accuracy: 0.5742
# Epoch 12/100
# 64/64 [==============================] - 15s 226ms/step - loss: 0.4902 - accuracy: 0.7744 - val_loss: 1.2130 - val_accuracy: 0.7891
# Epoch 13/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4949 - accuracy: 0.7852 - val_loss: 0.4051 - val_accuracy: 0.8203
# Epoch 14/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4945 - accuracy: 0.7900 - val_loss: 0.3612 - val_accuracy: 0.8789
# Epoch 15/100
# 64/64 [==============================] - 15s 227ms/step - loss: 0.4637 - accuracy: 0.7900 - val_loss: 4.1205 - val_accuracy: 0.8906
# Epoch 16/100
# 64/64 [==============================] - 15s 228ms/step - loss: 0.4734 - accuracy: 0.7822 - val_loss: 5.8289 - val_accuracy: 0.6211
# Epoch 17/100
# 64/64 [==============================] - 14s 225ms/step - loss: 0.4500 - accuracy: 0.7998 - val_loss: 0.3862 - val_accuracy: 0.8320
# Epoch 18/100
# 64/64 [==============================] - 15s 226ms/step - loss: 0.4565 - accuracy: 0.8105 - val_loss: 21.4973 - val_accuracy: 0.5391
# Epoch 19/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4308 - accuracy: 0.8037 - val_loss: 0.7432 - val_accuracy: 0.5664
# Epoch 20/100
# 64/64 [==============================] - 15s 239ms/step - loss: 0.4548 - accuracy: 0.7969 - val_loss: 1.8314 - val_accuracy: 0.6211
# Epoch 21/100
# 64/64 [==============================] - 14s 225ms/step - loss: 0.4612 - accuracy: 0.7930 - val_loss: 0.5989 - val_accuracy: 0.6797
# Epoch 22/100
# 64/64 [==============================] - 15s 227ms/step - loss: 0.4415 - accuracy: 0.8105 - val_loss: 3.0665 - val_accuracy: 0.7734
# Epoch 23/100
# 64/64 [==============================] - 15s 225ms/step - loss: 0.4454 - accuracy: 0.8057 - val_loss: 0.9585 - val_accuracy: 0.8477
# Epoch 24/100
# 64/64 [==============================] - 15s 227ms/step - loss: 0.4396 - accuracy: 0.8027 - val_loss: 0.3386 - val_accuracy: 0.9023
# Epoch 25/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4297 - accuracy: 0.8203 - val_loss: 0.7653 - val_accuracy: 0.6719
# Epoch 26/100
# 64/64 [==============================] - 15s 230ms/step - loss: 0.4182 - accuracy: 0.8193 - val_loss: 0.4542 - val_accuracy: 0.7734
# Epoch 27/100
# 64/64 [==============================] - 15s 226ms/step - loss: 0.4314 - accuracy: 0.7998 - val_loss: 0.5528 - val_accuracy: 0.7617
# Epoch 28/100
# 64/64 [==============================] - 15s 225ms/step - loss: 0.4207 - accuracy: 0.8018 - val_loss: 0.3708 - val_accuracy: 0.8594
# Epoch 29/100
# 64/64 [==============================] - 14s 222ms/step - loss: 0.4523 - accuracy: 0.8164 - val_loss: 0.4967 - val_accuracy: 0.7852
# Epoch 30/100
# 64/64 [==============================] - 15s 227ms/step - loss: 0.4025 - accuracy: 0.8145 - val_loss: 0.3206 - val_accuracy: 0.8672
# Epoch 31/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4185 - accuracy: 0.8115 - val_loss: 8.5600 - val_accuracy: 0.7461
# Epoch 32/100
# 64/64 [==============================] - 15s 226ms/step - loss: 0.4153 - accuracy: 0.8301 - val_loss: 11.3284 - val_accuracy: 0.7070
# Epoch 33/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4023 - accuracy: 0.8232 - val_loss: 0.5432 - val_accuracy: 0.6914
# Epoch 34/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4153 - accuracy: 0.8203 - val_loss: 0.7241 - val_accuracy: 0.8867
# Epoch 35/100
# 64/64 [==============================] - 15s 228ms/step - loss: 0.3968 - accuracy: 0.8281 - val_loss: 0.3751 - val_accuracy: 0.8438
# Epoch 36/100
# 64/64 [==============================] - 14s 222ms/step - loss: 0.4240 - accuracy: 0.8281 - val_loss: 0.3223 - val_accuracy: 0.8828
# Epoch 37/100
# 64/64 [==============================] - 15s 227ms/step - loss: 0.4117 - accuracy: 0.8242 - val_loss: 0.5656 - val_accuracy: 0.7227
# Epoch 38/100
# 64/64 [==============================] - 14s 223ms/step - loss: 0.3764 - accuracy: 0.8428 - val_loss: 2.4023 - val_accuracy: 0.8711
# Epoch 39/100
# 64/64 [==============================] - 15s 227ms/step - loss: 0.4351 - accuracy: 0.8096 - val_loss: 2.8618 - val_accuracy: 0.8164
# Epoch 40/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4174 - accuracy: 0.8115 - val_loss: 497.8353 - val_accuracy: 0.5391
# Epoch 41/100
# 64/64 [==============================] - 15s 225ms/step - loss: 0.4404 - accuracy: 0.8105 - val_loss: 1.4809 - val_accuracy: 0.4844
# Epoch 42/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4608 - accuracy: 0.7959 - val_loss: 0.3779 - val_accuracy: 0.8320
# Epoch 43/100
# 64/64 [==============================] - 15s 225ms/step - loss: 0.4127 - accuracy: 0.8311 - val_loss: 0.4690 - val_accuracy: 0.7500
# Epoch 44/100
# 64/64 [==============================] - 14s 221ms/step - loss: 0.4103 - accuracy: 0.8125 - val_loss: 0.3415 - val_accuracy: 0.8945
# Epoch 45/100
# 64/64 [==============================] - 15s 225ms/step - loss: 0.4281 - accuracy: 0.8076 - val_loss: 1.1387 - val_accuracy: 0.4844
# Epoch 46/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4114 - accuracy: 0.8193 - val_loss: 0.8112 - val_accuracy: 0.8477
# Epoch 47/100
# 64/64 [==============================] - 14s 221ms/step - loss: 0.4039 - accuracy: 0.8291 - val_loss: 0.4012 - val_accuracy: 0.8281
# Epoch 48/100
# 64/64 [==============================] - 15s 226ms/step - loss: 0.3967 - accuracy: 0.8232 - val_loss: 0.3191 - val_accuracy: 0.8633
# Epoch 49/100
# 64/64 [==============================] - 14s 220ms/step - loss: 0.4025 - accuracy: 0.8271 - val_loss: 0.4958 - val_accuracy: 0.6992
# Epoch 50/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4343 - accuracy: 0.8135 - val_loss: 59.4991 - val_accuracy: 0.7383
# Epoch 51/100
# 64/64 [==============================] - 14s 223ms/step - loss: 0.4192 - accuracy: 0.8213 - val_loss: 0.4214 - val_accuracy: 0.7891
# Epoch 52/100
# 64/64 [==============================] - 15s 227ms/step - loss: 0.4246 - accuracy: 0.8066 - val_loss: 133.3480 - val_accuracy: 0.4648
# Epoch 53/100
# 64/64 [==============================] - 14s 221ms/step - loss: 0.4313 - accuracy: 0.8174 - val_loss: 0.6847 - val_accuracy: 0.4961
# Epoch 54/100
# 64/64 [==============================] - 14s 221ms/step - loss: 0.3972 - accuracy: 0.8340 - val_loss: 0.5774 - val_accuracy: 0.6016
# Epoch 55/100
# 64/64 [==============================] - 14s 222ms/step - loss: 0.4056 - accuracy: 0.8252 - val_loss: 0.3095 - val_accuracy: 0.9180
# Epoch 56/100
# 64/64 [==============================] - 15s 226ms/step - loss: 0.4313 - accuracy: 0.8291 - val_loss: 1.6193 - val_accuracy: 0.7070
# Epoch 57/100
# 64/64 [==============================] - 14s 223ms/step - loss: 0.3882 - accuracy: 0.8467 - val_loss: 0.7249 - val_accuracy: 0.7344
# Epoch 58/100
# 64/64 [==============================] - 15s 226ms/step - loss: 0.4480 - accuracy: 0.8135 - val_loss: 1.0269 - val_accuracy: 0.8047
# Epoch 59/100
# 64/64 [==============================] - 14s 223ms/step - loss: 0.4363 - accuracy: 0.8105 - val_loss: 0.3611 - val_accuracy: 0.8516
# Epoch 60/100
# 64/64 [==============================] - 14s 222ms/step - loss: 0.4515 - accuracy: 0.8018 - val_loss: 0.4045 - val_accuracy: 0.8438
# Epoch 61/100
# 64/64 [==============================] - 14s 225ms/step - loss: 0.4566 - accuracy: 0.8105 - val_loss: 0.6583 - val_accuracy: 0.8203
# Epoch 62/100
# 64/64 [==============================] - 14s 221ms/step - loss: 0.4014 - accuracy: 0.8252 - val_loss: 0.4413 - val_accuracy: 0.8164
# Epoch 63/100
# 64/64 [==============================] - 14s 221ms/step - loss: 0.4655 - accuracy: 0.7949 - val_loss: 0.7534 - val_accuracy: 0.7969
# Epoch 64/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.3934 - accuracy: 0.8330 - val_loss: 0.4102 - val_accuracy: 0.8164
# Epoch 65/100
# 64/64 [==============================] - 15s 225ms/step - loss: 0.4074 - accuracy: 0.8369 - val_loss: 0.5528 - val_accuracy: 0.7031
# Epoch 66/100
# 64/64 [==============================] - 14s 221ms/step - loss: 0.3922 - accuracy: 0.8232 - val_loss: 0.6563 - val_accuracy: 0.6680
# Epoch 67/100
# 64/64 [==============================] - 14s 223ms/step - loss: 0.4094 - accuracy: 0.8291 - val_loss: 0.4410 - val_accuracy: 0.8008
# Epoch 68/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.3931 - accuracy: 0.8311 - val_loss: 0.3997 - val_accuracy: 0.8008
# Epoch 69/100
# 64/64 [==============================] - 15s 227ms/step - loss: 0.3788 - accuracy: 0.8438 - val_loss: 0.2940 - val_accuracy: 0.9141
# Epoch 70/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.3860 - accuracy: 0.8291 - val_loss: 0.6376 - val_accuracy: 0.6992
# Epoch 71/100
# 64/64 [==============================] - 14s 225ms/step - loss: 0.3725 - accuracy: 0.8467 - val_loss: 0.5042 - val_accuracy: 0.7461
# Epoch 72/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.3826 - accuracy: 0.8330 - val_loss: 243.8307 - val_accuracy: 0.5508
# Epoch 73/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4153 - accuracy: 0.8174 - val_loss: 0.5490 - val_accuracy: 0.6914
# Epoch 74/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4329 - accuracy: 0.8008 - val_loss: 0.6191 - val_accuracy: 0.6484
# Epoch 75/100
# 64/64 [==============================] - 14s 222ms/step - loss: 0.4136 - accuracy: 0.8203 - val_loss: 0.3107 - val_accuracy: 0.8789
# Epoch 76/100
# 64/64 [==============================] - 15s 227ms/step - loss: 0.4119 - accuracy: 0.8076 - val_loss: 0.4598 - val_accuracy: 0.7734
# Epoch 77/100
# 64/64 [==============================] - 14s 223ms/step - loss: 0.3971 - accuracy: 0.8203 - val_loss: 0.5106 - val_accuracy: 0.7266
# Epoch 78/100
# 64/64 [==============================] - 15s 225ms/step - loss: 0.3731 - accuracy: 0.8398 - val_loss: 0.3108 - val_accuracy: 0.8750
# Epoch 79/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4229 - accuracy: 0.8262 - val_loss: 0.3742 - val_accuracy: 0.8164
# Epoch 80/100
# 64/64 [==============================] - 14s 225ms/step - loss: 0.4305 - accuracy: 0.8135 - val_loss: 1.1494 - val_accuracy: 0.4844
# Epoch 81/100
# 64/64 [==============================] - 14s 223ms/step - loss: 0.4246 - accuracy: 0.8125 - val_loss: 0.4395 - val_accuracy: 0.7891
# Epoch 82/100
# 64/64 [==============================] - 15s 225ms/step - loss: 0.3892 - accuracy: 0.8301 - val_loss: 0.5228 - val_accuracy: 0.8477
# Epoch 83/100
# 64/64 [==============================] - 14s 220ms/step - loss: 0.3962 - accuracy: 0.8213 - val_loss: 0.4162 - val_accuracy: 0.8398
# Epoch 84/100
# 64/64 [==============================] - 14s 223ms/step - loss: 0.4309 - accuracy: 0.8096 - val_loss: 0.6282 - val_accuracy: 0.7188
# Epoch 85/100
# 64/64 [==============================] - 14s 219ms/step - loss: 0.4042 - accuracy: 0.8350 - val_loss: 0.3110 - val_accuracy: 0.8789
# Epoch 86/100
# 64/64 [==============================] - 14s 222ms/step - loss: 0.3743 - accuracy: 0.8389 - val_loss: 0.4742 - val_accuracy: 0.7812
# Epoch 87/100
# 64/64 [==============================] - 15s 226ms/step - loss: 0.4187 - accuracy: 0.8164 - val_loss: 0.4480 - val_accuracy: 0.7695
# Epoch 88/100
# 64/64 [==============================] - 14s 221ms/step - loss: 0.3644 - accuracy: 0.8418 - val_loss: 0.2912 - val_accuracy: 0.9258
# Epoch 89/100
# 64/64 [==============================] - 14s 222ms/step - loss: 0.4486 - accuracy: 0.7900 - val_loss: 79.8302 - val_accuracy: 0.6836
# Epoch 90/100
# 64/64 [==============================] - 14s 222ms/step - loss: 0.4108 - accuracy: 0.8105 - val_loss: 0.7417 - val_accuracy: 0.7891
# Epoch 91/100
# 64/64 [==============================] - 15s 227ms/step - loss: 0.4074 - accuracy: 0.8213 - val_loss: 0.3032 - val_accuracy: 0.8828
# Epoch 92/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4028 - accuracy: 0.8291 - val_loss: 4.2751 - val_accuracy: 0.7617
# Epoch 93/100
# 64/64 [==============================] - 14s 224ms/step - loss: 0.4058 - accuracy: 0.8232 - val_loss: 0.3048 - val_accuracy: 0.8789
# Epoch 94/100
# 64/64 [==============================] - 14s 221ms/step - loss: 0.4441 - accuracy: 0.8193 - val_loss: 1.2002 - val_accuracy: 0.4844
# Epoch 95/100
# 64/64 [==============================] - 15s 226ms/step - loss: 0.3889 - accuracy: 0.8291 - val_loss: 0.3864 - val_accuracy: 0.7812
# Epoch 96/100
# 64/64 [==============================] - 14s 222ms/step - loss: 0.3881 - accuracy: 0.8281 - val_loss: 0.8854 - val_accuracy: 0.5625
# Epoch 97/100
# 64/64 [==============================] - 14s 219ms/step - loss: 0.4523 - accuracy: 0.8115 - val_loss: 10.1943 - val_accuracy: 0.5469
# Epoch 98/100
# 64/64 [==============================] - 14s 221ms/step - loss: 0.4412 - accuracy: 0.8115 - val_loss: 0.4896 - val_accuracy: 0.8008
# Epoch 99/100
# 64/64 [==============================] - 14s 223ms/step - loss: 0.4300 - accuracy: 0.8164 - val_loss: 0.3576 - val_accuracy: 0.8281
# Epoch 100/100
# 64/64 [==============================] - 14s 219ms/step - loss: 0.4340 - accuracy: 0.8164 - val_loss: 9.9476 - val_accuracy: 0.7227

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()

history_df = pd.DataFrame(history.history)
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Prediction

# %%
y_val_pred = model.predict(x_val)
# Out:
# 8/8 [==============================] - 2s 72ms/step

# %%
accuracy_score(np.argmax(y_val, axis=1), np.argmax(y_val_pred, axis=1))
# Out:
# 0.72265625

# %%
y_pred = model.predict(x_test)
# Out:
# 8/8 [==============================] - 2s 59ms/step

# %%
steps = 10
predictions = []

for i in tqdm(range(steps)):
    preds = model.predict_generator(train_generator.flow(x_test, batch_size=BATCH_SIZE, shuffle=False),
                                    steps = len(x_test)/BATCH_SIZE)
    
    predictions.append(preds)
    gc.collect()
    
y_pred_tta = np.mean(predictions, axis=0)
# Out:
# 100%|██████████| 10/10 [00:39<00:00,  3.98s/it]

# %% [markdown]
# # Confusion Matrix

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Breast Cancer')
# Out:
# Confusion matrix, without normalization
# [[113   7]
#  [ 41  79]]

# %%
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred_tta, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Breast Cancer')
# Out:
# Confusion matrix, without normalization
# [[114   6]
#  [ 40  80]]

# %% [markdown]
# # Classification Report

# %%
from sklearn.metrics import classification_report
classification_report( np.argmax(y_test, axis=1), np.argmax(y_pred_tta, axis=1))
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.74      0.95      0.83       120\n           1       0.93      0.67      0.78       120\n\n    accuracy                           0.81       240\n   macro avg       0.84      0.81      0.80       240\nweighted avg       0.84      0.81      0.80       240\n'

# %% [markdown]
# # ROC & AUC

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(y_test, axis=1), np.argmax(y_pred_tta, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(y_test, axis=1), np.argmax(y_pred_tta, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()
